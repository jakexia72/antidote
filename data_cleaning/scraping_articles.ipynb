# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
from pymed import PubMed
import pandas as pd

    
# Step 1: Find links to all results pages
url_base = 'https://www.drugbank.ca/unearth/q?c=_score&d=down&query=alzheimer%27s&searcher=drugs'
page_base = urllib.request.urlopen(url_base)
soup_base = BeautifulSoup(page_base)

all_links = soup_base.find_all("a")

# Set stores all of our results pages
base_url_set = {url_base}

# Add to set all links (no duplicates)
for link in all_links:      
    current_link = link.get("href")
    
    if current_link is not None and "/unearth/q?c=" in current_link:
        base_url_set.add("https://www.drugbank.ca" + current_link)
        
# Initialize another set that stores all drug names (no duplicates)
drug_link_set = set()
drug_name_set = set()
    
# Loop through results urls and add all drug links to drug_link_set
for url in base_url_set:
    page = urllib.request.urlopen(url)
    soup = BeautifulSoup(page)
    drug_links = soup.find_all("a")
    
    for drug_link in drug_links:      
        current_link = drug_link.get("href")
        if current_link is not None and "/drugs/" in current_link:
            drug_name_set.add(drug_link.string)
            drug_link_set.add("https://www.drugbank.ca" + current_link)
            
# Initialize lists to store CHEMBL names + links
common_names = []
chembl_names = []
chembl_links = []
iupac_names = []

# Now we loop through the actual drug urls
for link in drug_link_set:
    page_drug = urllib.request.urlopen(link)
    soup_drug = BeautifulSoup(page_drug)
    drug_names = soup_drug.find_all("a")
    common_name = soup_drug.h1.string
    
    for d in drug_names:      
        current_link = d.get("href")
       
        if current_link is not None and "/chembldb/" in current_link:
            common_names.append(common_name)
            chembl_links.append(current_link)
            chembl_names.append(d.string)
            
for i in chembl_names:
    print(i)
    
for j in chembl_links:
    print(j)

for k in common_names:
    print(k)
    
pubmed = PubMed(tool="PubMedSearcher", email="myemail@ccc.com")

# Final drug lists: only those found to have relevant publications on PubMed make the final dataset
# so final drugs must have: chemblID + pubmed results
final_drug_common_names = set()
final_drug_chembl_names = set()
final_drug_chembl_links = set()

#test1 = []
#test2 = []
# Out:
# CHEMBL395280
# CHEMBL252556
# CHEMBL119385
# CHEMBL1277001
# CHEMBL259209
# CHEMBL95
# CHEMBL920
# CHEMBL3187683
# CHEMBL972
# CHEMBL521
# CHEMBL1047
# CHEMBL245079
# CHEMBL132966
# CHEMBL659
# CHEMBL2333941
# CHEMBL2177913
# CHEMBL134342
# CHEMBL260829
# CHEMBL121810
# CHEMBL1406148
# CHEMBL2087337
# CHEMBL1201199
# CHEMBL2387144
# CHEMBL112797
# CHEMBL2151437
# CHEMBL134713
# CHEMBL2151572
# CHEMBL4078588
# CHEMBL510539
# CHEMBL3634131
# CHEMBL121
# CHEMBL149082
# CHEMBL589390
# CHEMBL2179105
# CHEMBL493737
# CHEMBL3545349
# CHEMBL136800
# CHEMBL600
# CHEMBL1135
# CHEMBL1774461
# CHEMBL3989690
# CHEMBL3286580
# CHEMBL807
# CHEMBL1112
# CHEMBL2396989
# CHEMBL502
# CHEMBL75013
# CHEMBL2103826
# CHEMBL2110954
# CHEMBL159776
# CHEMBL2042122
# CHEMBL3545291
# CHEMBL1083390
# CHEMBL3545157
# CHEMBL3989929
# CHEMBL146624
# CHEMBL3301601
# CHEMBL74926
# CHEMBL2151439
# CHEMBL1224151
# CHEMBL127071
# CHEMBL2074932
# CHEMBL3306918
# CHEMBL476323
# CHEMBL405110
# CHEMBL3546271
# CHEMBL2107767
# CHEMBL1079905
# CHEMBL190083
# CHEMBL81421
# CHEMBL1512580
# CHEMBL636
# CHEMBL609
# CHEMBL575060
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL395280
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL252556
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL119385
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1277001
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL259209
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL95
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3187683
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL972
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL521
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1047
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL245079
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL132966
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2333941
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2177913
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL134342
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL260829
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121810
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1406148
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2087337
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1201199
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2387144
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL112797
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2151437
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL134713
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2151572
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL4078588
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL510539
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3634131
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2179105
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL493737
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3545349
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL136800
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL600
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1135
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1774461
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3989690
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3286580
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1112
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2396989
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL75013
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2103826
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2110954
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL159776
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2042122
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3545291
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1083390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3545157
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3989929
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL146624
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3301601
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2151439
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1224151
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL127071
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2074932
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3306918
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL476323
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL405110
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3546271
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2107767
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1079905
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL190083
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL81421
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1512580
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL609
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL575060
# Huperzine A
# Idebenone
# Neflamapimod
# Mibampator
# Milnacipran
# Tacrine
# Choline
# Arundic acid
# Selegiline
# Ibuprofen
# D-alpha-Tocopherol acetate
# Huperzine B
# Rivanicline
# Galantamine
# LY-2811376
# AZD-3839
# Lipoic acid
# Nefiracetam
# Ganstigmine
# Tricaprylin
# Velusetrag
# Leuprolide
# J147
# SGS-742
# AZD-0328
# GTS-21
# Encenicline
# MK-7622
# Echinacoside
# PBT-1033
# Rosiglitazone
# Tramiprosate
# Latrepirdine
# PF-04447943
# Methylinositol
# EVT-101
# CX516
# Acetylcysteine
# Deanol
# Florbetapir (18F)
# Tesofensine
# Idalopirdine
# Memantine
# Aripiprazole
# LY-2886721
# Donepezil
# Zanapezil
# Davunetide
# Neramexane
# Pramiracetam
# Flutemetamol (18F)
# JNJ-39393406
# Intepirdine
# Tideglusib
# Azeliragon
# Mitoglitazone
# Verubecestat
# Phenserine
# Facinicline
# E-2012
# Pozanicline
# 2-deoxyglucose
# PRX-03140
# MK-0249
# Methylene blue
# Flortaucipir
# Paliroden
# Propentofylline
# Tarenflurbil
# alpha-Tocopherol succinate
# Xaliproden
# Rivastigmine
# Triethylenetetramine
# Glutamic acid
# Huperzine A
#
# CHEMBL395280
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL395280
#
# Idebenone
#
#
# Neflamapimod
#
# CHEMBL119385
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL119385
#
# Mibampator
#
#
# Milnacipran
#
#
# Tacrine
#
# CHEMBL95
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL95
#
# Choline
#
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
#
# Arundic acid
#
#
# Selegiline
#
# CHEMBL972
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL972
#
# Ibuprofen
#
# CHEMBL521
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL521
# CHEMBL521
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL521
#
# D-alpha-Tocopherol acetate
#
#
# Huperzine B
#
#
# Rivanicline
#
#
# Galantamine
#
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# LY-2811376
#
#
# AZD-3839
#
#
# Lipoic acid
#
# CHEMBL134342
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL134342
#
# Nefiracetam
#
#
# Ganstigmine
#
# CHEMBL121810
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121810
#
# Tricaprylin
#
#
# Velusetrag
#
#
# Leuprolide
#
#
# J147
#
# CHEMBL2387144
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2387144
# CHEMBL2387144
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2387144
#
# SGS-742
#
#
# AZD-0328
#
#
# GTS-21
#
#
# Encenicline
#
#
# MK-7622
#
# CHEMBL4078588
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL4078588
#
# Echinacoside
#
#
# PBT-1033
#
#
# Rosiglitazone
#
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
#
# Tramiprosate
#
# CHEMBL149082
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082
# CHEMBL149082
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082
# CHEMBL149082
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082
#
# Latrepirdine
#
# CHEMBL589390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390
# CHEMBL589390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390
# CHEMBL589390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390
#
# PF-04447943
#
#
# Methylinositol
#
#
# EVT-101
#
#
# CX516
#
#
# Acetylcysteine
#
#
# Deanol
#
#
# Florbetapir (18F)
#
#
# Tesofensine
#
#
# Idalopirdine
#
#
# Memantine
#
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
#
# Aripiprazole
#
#
# LY-2886721
#
#
# Donepezil
#
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
#
# Zanapezil
#
#
# Davunetide
#
#
# Neramexane
#
#
# Pramiracetam
#
#
# Flutemetamol (18F)
#
#
# JNJ-39393406
#
#
# Intepirdine
#
#
# Tideglusib
#
# CHEMBL3545157
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3545157
#
# Azeliragon
#
# CHEMBL3989929
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3989929
#
# Mitoglitazone
#
#
# Verubecestat
#
# CHEMBL3301601
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3301601
#
# Phenserine
#
# CHEMBL74926
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926
# CHEMBL74926
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926
# CHEMBL74926
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926
#
# Facinicline
#
#
# E-2012
#
# CHEMBL1224151
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1224151
#
# Pozanicline
#
#
# 2-deoxyglucose
#
# CHEMBL2074932
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2074932
# CHEMBL2074932
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2074932
#
# PRX-03140
#
#
# MK-0249
#
#
# Methylene blue
#
# CHEMBL405110
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL405110
# CHEMBL405110
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL405110
#
# Flortaucipir
#
# CHEMBL3546271
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3546271
# CHEMBL3546271
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3546271
#
# Paliroden
#
#
# Propentofylline
#
#
# Tarenflurbil
#
# CHEMBL190083
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL190083
# CHEMBL190083
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL190083
#
# alpha-Tocopherol succinate
#
#
# Xaliproden
#
#
# Rivastigmine
#
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
#
# Triethylenetetramine
#
#
# Glutamic acid
#
#
# Lipoic acid
# Huperzine A
# Ibuprofen
# Latrepirdine
# Memantine
# Tacrine
# Selegiline
# Ganstigmine
# Tideglusib
# E-2012
# Neflamapimod
# Tramiprosate
# Tarenflurbil
# J147
# MK-7622
# Verubecestat
# Choline
# Azeliragon
# Rosiglitazone
# Flortaucipir
# Donepezil
# 2-deoxyglucose
# Galantamine
# Rivastigmine
# Phenserine
# Methylene blue
# CHEMBL119385
# CHEMBL521
# CHEMBL121810
# CHEMBL659
# CHEMBL1224151
# CHEMBL4078588
# CHEMBL405110
# CHEMBL3545157
# CHEMBL589390
# CHEMBL3301601
# CHEMBL95
# CHEMBL3546271
# CHEMBL972
# CHEMBL149082
# CHEMBL807
# CHEMBL121
# CHEMBL636
# CHEMBL2074932
# CHEMBL920
# CHEMBL190083
# CHEMBL134342
# CHEMBL502
# CHEMBL395280
# CHEMBL74926
# CHEMBL3989929
# CHEMBL2387144
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d8f500f92bcf> in <module>
#     122 # Generate Pandas DataFrame from list of dictionaries
#     123 df = pd.DataFrame.from_dict(final_drug_list)
# --> 124 export_csv = df.to_csv (r'C:\Users\jquin\Desktop\export_dataframe.csv', index = None, header=True)
#     125
#     126
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3227             decimal=decimal,
#    3228         )
# -> 3229         formatter.save()
#    3230
#    3231         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     395         if encoding:
#     396             # Encoding
# --> 397             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     398         elif is_text:
#     399             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\jquin\\Desktop\\export_dataframe.csv'

# %%
# Loop through drug names
for i, name in enumerate(common_names, 0):
    # Create a GraphQL query in plain text
    query = '\"alzheimers\"' + "+" + '\"' + name + '\"'
    
    # Execute the query against the API
    results = pubmed.query(query, max_results=100)
    
    print(name)
    print('')
    
    # Loop through article results
    for article in results:
#        test1.append(article.title)  
#        print(article.title)
#        test2.append(article.abstract)
        if article.title is not None and article.abstract is not None:
            if "alzheimer's" in article.abstract or "Alzheimer's" in article.abstract and name in article.abstract:
                final_drug_common_names.add(name)
#                print(name)
                final_drug_chembl_names.add(chembl_names[i])
                print(chembl_names[i])
                final_drug_chembl_links.add(chembl_links[i])
                print(chembl_links[i])
    print('')
    time.sleep(1)

for i in final_drug_common_names:
    print(i)
    
for i in final_drug_chembl_names:
    print(i)

#test3 = {"name": test1, "abstract": test2}
#df = pd.DataFrame.from_dict(test3)
#export_csv = df.to_csv (r'C:\Users\jquin\Desktop\export_dataframe.csv', index = None, header=True)

final_drug_list = {"common_name": list(final_drug_common_names), "chembl_name": list(final_drug_chembl_names), "chembl_link": list(final_drug_chembl_links)}
# Out:
# Huperzine A
#
# CHEMBL395280
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL395280
#
# Idebenone
#
#
# Neflamapimod
#
# CHEMBL119385
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL119385
#
# Mibampator
#
#
# Milnacipran
#
#
# Tacrine
#
# CHEMBL95
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL95
#
# Choline
#
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
# CHEMBL920
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920
#
# Arundic acid
#
#
# Selegiline
#
# CHEMBL972
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL972
#
# Ibuprofen
#
# CHEMBL521
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL521
# CHEMBL521
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL521
#
# D-alpha-Tocopherol acetate
#
#
# Huperzine B
#
#
# Rivanicline
#
#
# Galantamine
#
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
# CHEMBL659
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659
#
# LY-2811376
#
#
# AZD-3839
#
#
# Lipoic acid
#
# CHEMBL134342
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL134342
#
# Nefiracetam
#
#
# Ganstigmine
#
# CHEMBL121810
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121810
#
# Tricaprylin
#
#
# Velusetrag
#
#
# Leuprolide
#
#
# J147
#
# CHEMBL2387144
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2387144
# CHEMBL2387144
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2387144
#
# SGS-742
#
#
# AZD-0328
#
#
# GTS-21
#
#
# Encenicline
#
#
# MK-7622
#
# CHEMBL4078588
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL4078588
#
# Echinacoside
#
#
# PBT-1033
#
#
# Rosiglitazone
#
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
# CHEMBL121
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121
#
# Tramiprosate
#
# CHEMBL149082
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082
# CHEMBL149082
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082
# CHEMBL149082
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082
#
# Latrepirdine
#
# CHEMBL589390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390
# CHEMBL589390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390
# CHEMBL589390
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390
#
# PF-04447943
#
#
# Methylinositol
#
#
# EVT-101
#
#
# CX516
#
#
# Acetylcysteine
#
#
# Deanol
#
#
# Florbetapir (18F)
#
#
# Tesofensine
#
#
# Idalopirdine
#
#
# Memantine
#
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
# CHEMBL807
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807
#
# Aripiprazole
#
#
# LY-2886721
#
#
# Donepezil
#
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
# CHEMBL502
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502
#
# Zanapezil
#
#
# Davunetide
#
#
# Neramexane
#
#
# Pramiracetam
#
#
# Flutemetamol (18F)
#
#
# JNJ-39393406
#
#
# Intepirdine
#
#
# Tideglusib
#
# CHEMBL3545157
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3545157
#
# Azeliragon
#
# CHEMBL3989929
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3989929
#
# Mitoglitazone
#
#
# Verubecestat
#
# CHEMBL3301601
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3301601
#
# Phenserine
#
# CHEMBL74926
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926
# CHEMBL74926
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926
# CHEMBL74926
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926
#
# Facinicline
#
#
# E-2012
#
# CHEMBL1224151
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1224151
#
# Pozanicline
#
#
# 2-deoxyglucose
#
# CHEMBL2074932
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2074932
# CHEMBL2074932
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2074932
#
# PRX-03140
#
#
# MK-0249
#
#
# Methylene blue
#
# CHEMBL405110
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL405110
# CHEMBL405110
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL405110
#
# Flortaucipir
#
# CHEMBL3546271
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3546271
# CHEMBL3546271
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3546271
#
# Paliroden
#
#
# Propentofylline
#
#
# Tarenflurbil
#
# CHEMBL190083
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL190083
# CHEMBL190083
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL190083
#
# alpha-Tocopherol succinate
#
#
# Xaliproden
#
#
# Rivastigmine
#
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# CHEMBL636
# http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636
# Triethylenetetramine
#
#
# Glutamic acid
#
#
# Lipoic acid
# Huperzine A
# Ibuprofen
# Latrepirdine
# Memantine
# Tacrine
# Selegiline
# Ganstigmine
# Tideglusib
# E-2012
# Neflamapimod
# Tramiprosate
# Tarenflurbil
# J147
# MK-7622
# Verubecestat
# Choline
# Azeliragon
# Rosiglitazone
# Flortaucipir
# Donepezil
# 2-deoxyglucose
# Galantamine
# Rivastigmine
# Phenserine
# Methylene blue
# CHEMBL119385
# CHEMBL521
# CHEMBL121810
# CHEMBL659
# CHEMBL1224151
# CHEMBL4078588
# CHEMBL405110
# CHEMBL3545157
# CHEMBL589390
# CHEMBL3301601
# CHEMBL95
# CHEMBL3546271
# CHEMBL972
# CHEMBL149082
# CHEMBL807
# CHEMBL121
# CHEMBL636
# CHEMBL2074932
# CHEMBL920
# CHEMBL190083
# CHEMBL134342
# CHEMBL502
# CHEMBL395280
# CHEMBL74926
# CHEMBL3989929
# CHEMBL2387144

# %%
# Generate Pandas DataFrame from list of dictionaries
df = pd.DataFrame(final_drug_list)
export_csv = df.to_csv ('testquinto2.csv', index = None, header=True)

# %%
final_drug_list
# Out:
# {'common_name': ['Lipoic acid',
#   'Huperzine A',
#   'Ibuprofen',
#   'Latrepirdine',
#   'Memantine',
#   'Tacrine',
#   'Selegiline',
#   'Ganstigmine',
#   'Tideglusib',
#   'E-2012',
#   'Neflamapimod',
#   'Tramiprosate',
#   'Tarenflurbil',
#   'J147',
#   'MK-7622',
#   'Verubecestat',
#   'Choline',
#   'Azeliragon',
#   'Rosiglitazone',
#   'Flortaucipir',
#   'Donepezil',
#   '2-deoxyglucose',
#   'Galantamine',
#   'Rivastigmine',
#   'Phenserine',
#   'Methylene blue'],
#  'chembl_name': ['CHEMBL119385',
#   'CHEMBL521',
#   'CHEMBL121810',
#   'CHEMBL659',
#   'CHEMBL1224151',
#   'CHEMBL4078588',
#   'CHEMBL405110',
#   'CHEMBL3545157',
#   'CHEMBL589390',
#   'CHEMBL3301601',
#   'CHEMBL95',
#   'CHEMBL3546271',
#   'CHEMBL972',
#   'CHEMBL149082',
#   'CHEMBL807',
#   'CHEMBL121',
#   'CHEMBL636',
#   'CHEMBL2074932',
#   'CHEMBL920',
#   'CHEMBL190083',
#   'CHEMBL134342',
#   'CHEMBL502',
#   'CHEMBL395280',
#   'CHEMBL74926',
#   'CHEMBL3989929',
#   'CHEMBL2387144'],
#  'chembl_link': ['http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL405110',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL74926',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL134342',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL395280',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121810',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3545157',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL972',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL659',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2074932',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL1224151',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL119385',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL149082',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL636',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL2387144',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL807',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL95',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL121',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3989929',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL920',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL589390',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3546271',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL521',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL190083',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL4078588',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL502',
#   'http://www.ebi.ac.uk/chembldb/index.php/compound/inspect/CHEMBL3301601']}

# %%
common_namedf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f83601c9695f> in <module>
# ----> 1 common_namedf
#
# NameError: name 'common_namedf' is not defined

# %%
df2 = pd.DataFrame(final_drug_list)
# Out:
#     common_name    chembl_name  \
# 0   Lipoic acid   CHEMBL119385
# 1   Huperzine A      CHEMBL521
# 2     Ibuprofen   CHEMBL121810
# 3  Latrepirdine      CHEMBL659
# 4     Memantine  CHEMBL1224151
#
#                                          chembl_link
# 0  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 1  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 2  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 3  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 4  http://www.ebi.ac.uk/chembldb/index.php/compou...

# %%
df2
# Out:
#        common_name    chembl_name  \
# 0      Lipoic acid   CHEMBL119385
# 1      Huperzine A      CHEMBL521
# 2        Ibuprofen   CHEMBL121810
# 3     Latrepirdine      CHEMBL659
# 4        Memantine  CHEMBL1224151
# 5          Tacrine  CHEMBL4078588
# 6       Selegiline   CHEMBL405110
# 7      Ganstigmine  CHEMBL3545157
# 8       Tideglusib   CHEMBL589390
# 9           E-2012  CHEMBL3301601
# 10    Neflamapimod       CHEMBL95
# 11    Tramiprosate  CHEMBL3546271
# 12    Tarenflurbil      CHEMBL972
# 13            J147   CHEMBL149082
# 14         MK-7622      CHEMBL807
# 15    Verubecestat      CHEMBL121
# 16         Choline      CHEMBL636
# 17      Azeliragon  CHEMBL2074932
# 18   Rosiglitazone      CHEMBL920
# 19    Flortaucipir   CHEMBL190083
# 20       Donepezil   CHEMBL134342
# 21  2-deoxyglucose      CHEMBL502
# 22     Galantamine   CHEMBL395280
# 23    Rivastigmine    CHEMBL74926
# 24      Phenserine  CHEMBL3989929
# 25  Methylene blue  CHEMBL2387144
#
#                                           chembl_link
# 0   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 1   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 2   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 3   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 4   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 5   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 6   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 7   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 8   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 9   http://www.ebi.ac.uk/chembldb/index.php/compou...
# 10  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 11  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 12  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 13  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 14  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 15  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 16  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 17  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 18  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 19  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 20  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 21  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 22  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 23  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 24  http://www.ebi.ac.uk/chembldb/index.php/compou...
# 25  http://www.ebi.ac.uk/chembldb/index.php/compou...
