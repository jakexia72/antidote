# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'https://pubchem.ncbi.nlm.nih.gov/compound/50942'

page = urllib.request.urlopen(url)

# %%
soup = BeautifulSoup(page)

# %%
x = soup.find_all("js-rendered-content")
x
# Out:
# []

# %%
soup.findAll('td')[0]
link = one_a_tag['href']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-154832026430> in <module>
# ----> 1 soup.findAll('td')[0]
#       2 link = one_a_tag['href']
#
# IndexError: list index out of range

# %%
test = soup.findAll('td')[279]
test.text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-f29721323677> in <module>
# ----> 1 test = soup.findAll('td')[279]
#       2 test.text
#
# IndexError: list index out of range

# %%
import pandas as pd

new = pd.DataFrame()
dates = []
prices = []

# %%
for i in range(6,280):
    tag = soup.findAll('td')[i]
    if i%2 == 0:
        dates.append(tag.text)
    else:
        prices.append(tag.text)

# %%
new['date'] = dates
new['price'] = prices

# %%
new
# Out:
#             date    price
# 0    11 Jul 2019  1407.83
# 1    10 Jul 2019   1418.7
# 2    09 Jul 2019  1397.26
# 3    08 Jul 2019  1395.34
# 4    05 Jul 2019  1398.95
# 5    04 Jul 2019  1415.07
# 6    03 Jul 2019  1418.46
# 7    02 Jul 2019  1418.44
# 8    01 Jul 2019  1384.02
# 9    28 Jun 2019  1409.25
# 10   27 Jun 2019  1409.64
# 11   26 Jun 2019  1408.81
# 12   25 Jun 2019  1423.19
# 13   24 Jun 2019  1419.48
# 14   21 Jun 2019  1399.21
# 15   20 Jun 2019  1388.25
# 16   19 Jun 2019  1360.11
# 17   18 Jun 2019  1346.26
# 18   17 Jun 2019  1339.39
# 19   14 Jun 2019  1341.58
# 20   13 Jun 2019  1341.97
# 21   12 Jun 2019  1333.29
# 22   11 Jun 2019  1326.19
# 23   10 Jun 2019  1327.79
# 24   07 Jun 2019  1340.34
# 25   06 Jun 2019  1335.17
# 26   05 Jun 2019  1330.06
# 27   04 Jun 2019  1325.25
# 28   03 Jun 2019  1325.11
# 29   31 May 2019   1305.2
# ..           ...      ...
# 107  12 Feb 2019  1310.58
# 108  11 Feb 2019  1307.85
# 109  08 Feb 2019  1314.25
# ...

# %%
new.to_csv("golddaily.csv")
